# %%
import pandas as pd

# %%
ipl= pd.read_csv('matches.csv')

# %%
ipl
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1      2    2017       Pune  06/04/17               Mumbai Indians
# 2      3    2017     Rajkot  07/04/17                Gujarat Lions
# 3      4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4      5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
ipl.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1   2    2017       Pune  06/04/17               Mumbai Indians
# 2   3    2017     Rajkot  07/04/17                Gujarat Lions
# 3   4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4   5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
ipl.tail()
# Out:
#       id  season       city      date                team1  \
# 631  632    2016     Raipur  22/05/16     Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16        Gujarat Lions
# 633  634    2016      Delhi  25/05/16  Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16        Gujarat Lions
# 635  636    2016  Bangalore  29/05/16  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
ipl=pd.read_csv('https://raw.githubusercontent.com/training-ml/Files/main/matches.csv')

# %%
ipl
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1      2    2017       Pune  06/04/17               Mumbai Indians
# 2      3    2017     Rajkot  07/04/17                Gujarat Lions
# 3      4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4      5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
ipl.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  05/04/17          Sunrisers Hyderabad
# 1   2    2017       Pune  06/04/17               Mumbai Indians
# 2   3    2017     Rajkot  07/04/17                Gujarat Lions
# 3   4    2017     Indore  08/04/17       Rising Pune Supergiant
# 4   5    2017  Bangalore  08/04/17  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
ipl.shape
# Out:
# (636, 18)

# %%
#Fetching random rows.

ipl.sample(n=7)
# Out:
#       id  season        city      date                        team1  \
# 207  208    2010     Kolkata  04/04/10        Kolkata Knight Riders
# 447  448    2013  Chandigarh  06/05/13  Royal Challengers Bangalore
# 12    13    2017      Rajkot  14/04/17       Rising Pune Supergiant
# 473  474    2014     Sharjah  27/04/14          Sunrisers Hyderabad
# 209  210    2010      Nagpur  05/04/10             Rajasthan Royals
# 87    88    2008     Kolkata  08/05/08        Kolkata Knight Riders
# 80    81    2008  Chandigarh  03/05/08              Kings XI Punjab
#
#                            team2            toss_winner toss_decision  result  \
# 207              Kings XI Punjab  Kolkata Knight Riders           bat  normal
# 447              Kings XI Punjab        Kings XI Punjab         field  normal
# 12                 Gujarat Lions          Gujarat Lions         field  normal
# 473          Chennai Super Kings    Sunrisers Hyderabad           bat  normal
# ...

# %%
#Check the type of file.

type(ipl)
# Out:
# pandas.core.frame.DataFrame

# %%
excel_file= pd.read_excel(r'C:\Users\singh\OneDrive\Desktop\score_file.xlsx',sheet_name='score_file')

excel_file
# Out:
#     gender  student_id  marks
# 0     Male         105     50
# 1     Male         106     80
# 2   Female         107     90
# 3     Male         108     66
# 4   Female         109     55
# 5     Male         110     44
# 6     Male         111     29
# 7   Female         112     13
# 8     Male         113     12
# 9   Female         114     34
# 10    Male         115     36
# 11    Male         116     41
# 12  Female         117     52
# 13    Male         118     67
# 14  Female         119     84
# 15    Male         120     85
# 16    Male         121     89
# 17  Female         122     95
# 18    Male         123     96
# 19  Female         124     78
# 20    Male         125     77
# 21    Male         126     76
# 22  Female         127     71
# 23    Male         128     72
# 24  Female         129     70

# %%
#Export to current folder.

ipl.to_csv('ipl_copy.csv')

# %%
#Export to different folder by giving the as shown below.

ipl.to_csv(r'C:\Users\singh\ipl_copy.csv',
          index= False, header= True)
